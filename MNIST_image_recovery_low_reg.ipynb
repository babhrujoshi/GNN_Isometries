# %%
using NBInclude
@nbinclude("functions.ipynb")
function load_model_identity(load_dir::String, epoch::Int)
    print("Loading model...")
    @load joinpath(load_dir, "model-$epoch.bson") encoder_μ encoder_logvar decoder decoder_last
    println("Done")
    return encoder_μ, encoder_logvar, decoder, decoder_last
    
end

function get_train_loader(batch_size, shuffle::Bool)
    # The MNIST training set is made up of 60k 28 by 28 greyscale images
    train_x, train_y = MNIST.traindata(Float32)
    train_x = 1 .- reshape(train_x, (784, :))
    return DataLoader((train_x, train_y), batchsize=batch_size, shuffle=shuffle, partial=false)
end

function get_test_loader(batch_size, shuffle::Bool)
    # The FashionMNIST test set is made up of 10k 28 by 28 greyscale images
    test_x, test_y = MNIST.testdata(Float32)
    test_x = 1 .- reshape(test_x, (784, :))
    return DataLoader((test_x, test_y), batchsize=batch_size, shuffle=shuffle)
end
# Out:
# All function imported
# WARNING: using JLD.@load in module Main conflicts with an existing identifier.
# get_test_loader (generic function with 1 method)

# %%
# pick a image in MNIST to denoise
num = 5
batch_size = 64
shuffle_data = true
dataloader = get_test_loader(batch_size, shuffle_data)

(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent


epoch_to_load_inco = 35
dir_inco = "trained_GNN/MNIST_identity_v3"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco)


# Load the model and test set loader unenforced
epoch_to_load_co = 20
dir_co = "trained_GNN/MNIST_v2"
encoder_μ_co, encoder_logvar_co, decoder_co, W3_co = load_model_identity(dir_co, epoch_to_load_co);
μ = encoder_μ_co(x_true)
logvar_co = encoder_logvar_co(x_true)
# Apply reparameterisation trick to sample latent
z_co = μ + randn(Float32, size(logvar_co)) .* exp.(0.5f0 * logvar_co)


#setup
x_dim = 784
k = 20
tolerance = 1e-7; max_iter = 5000; out_toggle = 0
opt = Flux.Optimise.ADAM(.1);


G_inco(z) = W3_inco *decoder_inco(z)
G_co(z) = W3_co *decoder_co(z)
colorview(Gray, reshape(G_inco(z_inco), 28,28)' )
# Out:
# ┌ Warning: MNIST.testdata() is deprecated, use `MNIST(split=:test)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:195
# Loading model...Done
# Loading model...Done
# 28×28 reinterpret(reshape, Gray{Float64}, adjoint(::Matrix{Float64})) with eltype Gray{Float64}:
#  Gray{Float64}(9.98547)  Gray{Float64}(12.9576)  …  Gray{Float64}(9.36087)
#  Gray{Float64}(8.07997)  Gray{Float64}(9.77387)     Gray{Float64}(9.56234)
#  Gray{Float64}(10.1038)  Gray{Float64}(9.29231)     Gray{Float64}(9.85538)
#  Gray{Float64}(10.7272)  Gray{Float64}(9.3648)      Gray{Float64}(11.4268)
#  Gray{Float64}(9.71167)  Gray{Float64}(8.91324)     Gray{Float64}(9.47304)
#  Gray{Float64}(10.1774)  Gray{Float64}(10.6243)  …  Gray{Float64}(9.54906)
#  Gray{Float64}(7.84733)  Gray{Float64}(10.4521)     Gray{Float64}(9.54331)
#  Gray{Float64}(11.493)   Gray{Float64}(10.5944)     Gray{Float64}(9.14416)
#  Gray{Float64}(10.6769)  Gray{Float64}(8.68103)     Gray{Float64}(9.40639)
#  Gray{Float64}(8.51222)  Gray{Float64}(8.76187)     Gray{Float64}(8.90116)
#  Gray{Float64}(11.2303)  Gray{Float64}(8.83811)  …  Gray{Float64}(9.78593)
#  Gray{Float64}(9.79175)  Gray{Float64}(7.09419)     Gray{Float64}(9.04642)
#  Gray{Float64}(10.6003)  Gray{Float64}(9.46984)     Gray{Float64}(7.18935)
#  ⋮                                               ⋱
#  Gray{Float64}(9.95799)  Gray{Float64}(7.42313)     Gray{Float64}(8.74564)
#  Gray{Float64}(8.45876)  Gray{Float64}(12.0288)     Gray{Float64}(9.83772)
#  Gray{Float64}(8.59305)  Gray{Float64}(12.0912)     Gray{Float64}(8.39246)
#  Gray{Float64}(10.6182)  Gray{Float64}(12.7879)     Gray{Float64}(9.03001)
#  Gray{Float64}(10.0735)  Gray{Float64}(10.1767)  …  Gray{Float64}(9.64986)
#  Gray{Float64}(8.54561)  Gray{Float64}(8.96862)     Gray{Float64}(10.8855)
#  Gray{Float64}(11.5317)  Gray{Float64}(8.68647)     Gray{Float64}(11.1512)
#  Gray{Float64}(9.91968)  Gray{Float64}(17.4438)     Gray{Float64}(11.5114)
#  Gray{Float64}(10.2432)  Gray{Float64}(11.483)      Gray{Float64}(10.9474)
#  Gray{Float64}(11.0778)  Gray{Float64}(10.8153)  …  Gray{Float64}(11.1051)
#  Gray{Float64}(11.1507)  Gray{Float64}(12.9681)     Gray{Float64}(13.3672)
#  Gray{Float64}(12.9579)  Gray{Float64}(11.3005)     Gray{Float64}(12.7927)

# %%
epoch_to_load_inco = 35
dir_inco = "trained_GNN/MNIST_identity_v3"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
F = dct(diagm(ones(x_dim)),2);
print("$(subspace_incoherence(F, W3_inco)), $(norm(W3_inco'*W3_co - I(500), 2))")
# Out:
# Loading model...Done
# 0.849799593907456, 179.66925438635394

# %%
m_list = 10:5:100
z_est_inco_list = zeros(k, length(m_list))
z_est_co_list = zeros(k, length(m_list))

Threads.@threads for i in 1:length(m_list)
    m = m_list[i]
    F_sub = sample_fourier(m, x_dim)  # subsampling DCT for measurement matrix
    F_sub = F_sub * sqrt(x_dim)/sqrt(m); #normalization  

    y = F_sub * G_inco(z_inco) # measurement vector using subsampled DCT matrix
    z_est_inco = randn(k) #initialization for algorithm
    z_est_inco = estimated_code(opt, G_inco, y, F_sub, z_est_inco; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_inco_list[:,i] = z_est_inco

    y = F_sub * G_co(z_co) # measurement vector using subsampled DCT matrix
    z_est_co = randn(k) #initialization for algorithm
    z_est_co = estimated_code(opt, G_co, y, F_sub, z_est_co; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_co_list[:,i] = z_est_co
end

# %%
anim = @animate for k ∈ 1:length(m_list)
    p1 = plot(colorview(Gray, reshape(G_inco(z_inco), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .81")
    p2 = plot(colorview(Gray, reshape(G_inco(z_est_inco_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    p3 = plot(colorview(Gray, reshape(G_co(z_co), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .97")
    p4 = plot(colorview(Gray, reshape(G_co(z_est_co_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    plot(p1, p2, p3, p4, layout = grid(2,2))
end
gif(anim, fps = 1)
# gif(anim, "anim_5.gif", fps = 1)
# Out:
# ┌ Info: Saved animation to
# │   fn = c:\Users\Babhru\Documents\GitHub\GNN_Isometries\tmp.gif
# └ @ Plots C:\Users\Babhru\.julia\packages\Plots\E2187\src\animation.jl:126
# Plots.AnimatedGif("c:\\Users\\Babhru\\Documents\\GitHub\\GNN_Isometries\\tmp.gif")

# %%
# pick a image in MNIST to denoise
num = 1
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)

(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco)


# Load the model and test set loader unenforced
epoch_to_load_co = 20
dir_co = "trained_GNN/MNIST_v2"
encoder_μ_co, encoder_logvar_co, decoder_co, W3_co = load_model_identity(dir_co, epoch_to_load_co);
μ = encoder_μ_co(x_true)
logvar_co = encoder_logvar_co(x_true)
# Apply reparameterisation trick to sample latent
z_co = μ + randn(Float32, size(logvar_co)) .* exp.(0.5f0 * logvar_co)


#setup
x_dim = 784
k = 20
tolerance = 1e-7; max_iter = 3000; out_toggle = 0
opt = Flux.Optimise.ADAM(.1);

G_inco(z) = W3_inco *decoder_inco(z)
G_co(z) = W3_co *decoder_co(z)
colorview(Gray, reshape(G_co(z_co), 28,28)' )
# Out:
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# Loading model...Done
# Loading model...Done
# 28×28 reinterpret(reshape, Gray{Float64}, adjoint(::Matrix{Float64})) with eltype Gray{Float64}:
#  Gray{Float64}(13.1594)  Gray{Float64}(13.1578)  …  Gray{Float64}(13.1582)
#  Gray{Float64}(13.1596)  Gray{Float64}(13.16)       Gray{Float64}(13.1594)
#  Gray{Float64}(13.1593)  Gray{Float64}(13.1593)     Gray{Float64}(13.1589)
#  Gray{Float64}(13.1588)  Gray{Float64}(13.1582)     Gray{Float64}(13.1593)
#  Gray{Float64}(13.1618)  Gray{Float64}(13.4324)     Gray{Float64}(12.8123)
#  Gray{Float64}(13.1578)  Gray{Float64}(13.159)   …  Gray{Float64}(10.8579)
#  Gray{Float64}(13.1579)  Gray{Float64}(13.2785)     Gray{Float64}(9.78705)
#  Gray{Float64}(13.4713)  Gray{Float64}(11.8844)     Gray{Float64}(11.6029)
#  Gray{Float64}(13.615)   Gray{Float64}(13.7755)     Gray{Float64}(13.0769)
#  Gray{Float64}(13.4889)  Gray{Float64}(13.9704)     Gray{Float64}(12.6002)
#  Gray{Float64}(13.4443)  Gray{Float64}(13.4288)  …  Gray{Float64}(12.6385)
#  Gray{Float64}(13.5147)  Gray{Float64}(13.1244)     Gray{Float64}(12.5186)
#  Gray{Float64}(13.1278)  Gray{Float64}(14.2409)     Gray{Float64}(12.0174)
#  ⋮                                               ⋱
#  Gray{Float64}(13.4432)  Gray{Float64}(13.4116)     Gray{Float64}(10.144)
#  Gray{Float64}(13.1603)  Gray{Float64}(12.4377)     Gray{Float64}(13.049)
#  Gray{Float64}(13.3703)  Gray{Float64}(13.1901)     Gray{Float64}(11.5718)
#  Gray{Float64}(13.3068)  Gray{Float64}(12.4393)     Gray{Float64}(11.9856)
#  Gray{Float64}(13.1624)  Gray{Float64}(12.3753)  …  Gray{Float64}(13.048)
#  Gray{Float64}(13.3195)  Gray{Float64}(12.1722)     Gray{Float64}(13.4826)
#  Gray{Float64}(13.3273)  Gray{Float64}(13.4766)     Gray{Float64}(13.4962)
#  Gray{Float64}(13.1581)  Gray{Float64}(13.1586)     Gray{Float64}(13.1588)
#  Gray{Float64}(13.1587)  Gray{Float64}(13.1614)     Gray{Float64}(13.1592)
#  Gray{Float64}(13.1597)  Gray{Float64}(13.1602)  …  Gray{Float64}(13.1599)
#  Gray{Float64}(13.159)   Gray{Float64}(13.1596)     Gray{Float64}(13.1582)
#  Gray{Float64}(13.1596)  Gray{Float64}(13.1599)     Gray{Float64}(13.1595)

# %%
m_list = 10:5:100
z_est_inco_list = zeros(k, length(m_list))
z_est_co_list = zeros(k, length(m_list))

Threads.@threads for i in 1:length(m_list)
    m = m_list[i]
    F_sub = sample_fourier(m, x_dim)  # subsampling DCT for measurement matrix
    F_sub = F_sub * sqrt(x_dim)/sqrt(m); #normalization  

    y = F_sub * G_inco(z_inco) # measurement vector using subsampled DCT matrix
    z_est_inco = randn(k) #initialization for algorithm
    z_est_inco = estimated_code(opt, G_inco, y, F_sub, z_est_inco; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_inco_list[:,i] = z_est_inco

    y = F_sub * G_co(z_co) # measurement vector using subsampled DCT matrix
    z_est_co = randn(k) #initialization for algorithm
    z_est_co = estimated_code(opt, G_co, y, F_sub, z_est_co; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_co_list[:,i] = z_est_co
end

# %%
anim = @animate for k ∈ 1:length(m_list)
    p1 = plot(colorview(Gray, reshape(G_inco(z_inco), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .81")
    p2 = plot(colorview(Gray, reshape(G_inco(z_est_inco_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    p3 = plot(colorview(Gray, reshape(G_co(z_co), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .97")
    p4 = plot(colorview(Gray, reshape(G_co(z_est_co_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    plot(p1, p2, p3, p4, layout = grid(2,2))
end

gif(anim, "anim_$num.gif", fps = 1)
# Out:
# ┌ Info: Saved animation to
# │   fn = c:\Users\Babhru\Documents\GitHub\GNN_Isometries\anim_1.gif
# └ @ Plots C:\Users\Babhru\.julia\packages\Plots\E2187\src\animation.jl:126
# Plots.AnimatedGif("c:\\Users\\Babhru\\Documents\\GitHub\\GNN_Isometries\\anim_1.gif")

# %%
# pick a image in MNIST to denoise
num = 7
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)

(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco)


# Load the model and test set loader unenforced
epoch_to_load_co = 20
dir_co = "trained_GNN/MNIST_v2"
encoder_μ_co, encoder_logvar_co, decoder_co, W3_co = load_model_identity(dir_co, epoch_to_load_co);
μ = encoder_μ_co(x_true)
logvar_co = encoder_logvar_co(x_true)
# Apply reparameterisation trick to sample latent
z_co = μ + randn(Float32, size(logvar_co)) .* exp.(0.5f0 * logvar_co)


#setup
x_dim = 784
k = 20
tolerance = 1e-7; max_iter = 3000; out_toggle = 0
opt = Flux.Optimise.ADAM(.1);

G_inco(z) = W3_inco *decoder_inco(z)
G_co(z) = W3_co *decoder_co(z)
colorview(Gray, reshape(G_inco(z_inco), 28,28)' )
# Out:
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# Loading model...Done
# Loading model...Done
# 28×28 reinterpret(reshape, Gray{Float64}, adjoint(::Matrix{Float64})) with eltype Gray{Float64}:
#  Gray{Float64}(7.74666)  Gray{Float64}(15.0505)  …  Gray{Float64}(7.86246)
#  Gray{Float64}(9.08307)  Gray{Float64}(25.4429)     Gray{Float64}(11.9281)
#  Gray{Float64}(23.0768)  Gray{Float64}(15.3873)     Gray{Float64}(11.5131)
#  Gray{Float64}(16.7484)  Gray{Float64}(10.5094)     Gray{Float64}(18.5759)
#  Gray{Float64}(9.83707)  Gray{Float64}(49.0397)     Gray{Float64}(26.079)
#  Gray{Float64}(17.1607)  Gray{Float64}(10.7771)  …  Gray{Float64}(7.49772)
#  Gray{Float64}(27.149)   Gray{Float64}(16.9112)     Gray{Float64}(53.7012)
#  Gray{Float64}(6.77789)  Gray{Float64}(16.0466)     Gray{Float64}(21.6046)
#  Gray{Float64}(10.3618)  Gray{Float64}(7.41902)     Gray{Float64}(24.3825)
#  Gray{Float64}(13.9129)  Gray{Float64}(14.2961)     Gray{Float64}(28.3065)
#  ⋮                                               ⋱
#  Gray{Float64}(17.8952)  Gray{Float64}(11.2863)     Gray{Float64}(27.1935)
#  Gray{Float64}(24.1789)  Gray{Float64}(36.9248)  …  Gray{Float64}(8.85497)
#  Gray{Float64}(33.6947)  Gray{Float64}(9.8337)      Gray{Float64}(28.2531)
#  Gray{Float64}(12.0221)  Gray{Float64}(12.6728)     Gray{Float64}(23.9677)
#  Gray{Float64}(20.9168)  Gray{Float64}(11.4526)     Gray{Float64}(36.4469)
#  Gray{Float64}(9.51489)  Gray{Float64}(71.7729)     Gray{Float64}(14.3242)
#  Gray{Float64}(22.1729)  Gray{Float64}(36.4343)  …  Gray{Float64}(36.8967)
#  Gray{Float64}(10.9897)  Gray{Float64}(10.6496)     Gray{Float64}(15.8363)
#  Gray{Float64}(18.8585)  Gray{Float64}(19.6197)     Gray{Float64}(22.8958)

# %%
m_list = 10:5:100
z_est_inco_list = zeros(k, length(m_list))
z_est_co_list = zeros(k, length(m_list))

Threads.@threads for i in 1:length(m_list)
    m = m_list[i]
    F_sub = sample_fourier(m, x_dim)  # subsampling DCT for measurement matrix
    F_sub = F_sub * sqrt(x_dim)/sqrt(m); #normalization  

    y = F_sub * G_inco(z_inco) # measurement vector using subsampled DCT matrix
    z_est_inco = randn(k) #initialization for algorithm
    z_est_inco = estimated_code(opt, G_inco, y, F_sub, z_est_inco; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_inco_list[:,i] = z_est_inco

    y = F_sub * G_co(z_co) # measurement vector using subsampled DCT matrix
    z_est_co = randn(k) #initialization for algorithm
    z_est_co = estimated_code(opt, G_co, y, F_sub, z_est_co; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_co_list[:,i] = z_est_co
end

# %%
anim = @animate for k ∈ 1:length(m_list)
    p1 = plot(colorview(Gray, reshape(G_inco(z_inco), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .81")
    p2 = plot(colorview(Gray, reshape(G_inco(z_est_inco_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    p3 = plot(colorview(Gray, reshape(G_co(z_co), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .97")
    p4 = plot(colorview(Gray, reshape(G_co(z_est_co_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    plot(p1, p2, p3, p4, layout = grid(2,2))
end

gif(anim, "anim_$num.gif", fps = 1)
# Out:
# ┌ Info: Saved animation to
# │   fn = c:\Users\Babhru\Documents\GitHub\GNN_Isometries\anim_7.gif
# └ @ Plots C:\Users\Babhru\.julia\packages\Plots\E2187\src\animation.jl:126
# Plots.AnimatedGif("c:\\Users\\Babhru\\Documents\\GitHub\\GNN_Isometries\\anim_7.gif")

# %%
# pick a image in MNIST to denoise
num = 3
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)

(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco)


# Load the model and test set loader unenforced
epoch_to_load_co = 20
dir_co = "trained_GNN/MNIST_v2"
encoder_μ_co, encoder_logvar_co, decoder_co, W3_co = load_model_identity(dir_co, epoch_to_load_co);
μ = encoder_μ_co(x_true)
logvar_co = encoder_logvar_co(x_true)
# Apply reparameterisation trick to sample latent
z_co = μ + randn(Float32, size(logvar_co)) .* exp.(0.5f0 * logvar_co)


#setup
x_dim = 784
k = 20
tolerance = 1e-7; max_iter = 3000; out_toggle = 0
opt = Flux.Optimise.ADAM(.1);

G_inco(z) = W3_inco *decoder_inco(z)
G_co(z) = W3_co *decoder_co(z)
colorview(Gray, reshape(G_co(z_co), 28,28)' )
# Out:
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# Loading model...Done
# Loading model...Done
# 28×28 reinterpret(reshape, Gray{Float64}, adjoint(::Matrix{Float64})) with eltype Gray{Float64}:
#  Gray{Float64}(11.3543)  Gray{Float64}(11.3533)  …  Gray{Float64}(11.3538)
#  Gray{Float64}(11.3549)  Gray{Float64}(11.3554)     Gray{Float64}(11.3548)
#  Gray{Float64}(11.3547)  Gray{Float64}(11.3543)     Gray{Float64}(11.3543)
#  Gray{Float64}(11.3541)  Gray{Float64}(11.3539)     Gray{Float64}(11.3547)
#  Gray{Float64}(11.3538)  Gray{Float64}(11.5301)     Gray{Float64}(11.6582)
#  Gray{Float64}(11.3535)  Gray{Float64}(11.3542)  …  Gray{Float64}(10.5771)
#  Gray{Float64}(11.3534)  Gray{Float64}(11.4155)     Gray{Float64}(10.517)
#  Gray{Float64}(11.5492)  Gray{Float64}(9.33299)     Gray{Float64}(11.1626)
#  Gray{Float64}(11.4207)  Gray{Float64}(10.3811)     Gray{Float64}(11.9149)
#  Gray{Float64}(11.4153)  Gray{Float64}(10.749)      Gray{Float64}(11.602)
#  ⋮                                               ⋱
#  Gray{Float64}(11.508)   Gray{Float64}(10.8945)     Gray{Float64}(10.5537)
#  Gray{Float64}(11.3537)  Gray{Float64}(9.70911)  …  Gray{Float64}(11.5608)
#  Gray{Float64}(11.55)    Gray{Float64}(9.62072)     Gray{Float64}(11.3864)
#  Gray{Float64}(11.5488)  Gray{Float64}(11.4499)     Gray{Float64}(11.2042)
#  Gray{Float64}(11.3536)  Gray{Float64}(11.3539)     Gray{Float64}(11.3541)
#  Gray{Float64}(11.3541)  Gray{Float64}(11.3545)     Gray{Float64}(11.3542)
#  Gray{Float64}(11.3551)  Gray{Float64}(11.355)   …  Gray{Float64}(11.3548)
#  Gray{Float64}(11.3545)  Gray{Float64}(11.3549)     Gray{Float64}(11.3538)
#  Gray{Float64}(11.3548)  Gray{Float64}(11.3553)     Gray{Float64}(11.3548)

# %%
m_list = 10:5:100
z_est_inco_list = zeros(k, length(m_list))
z_est_co_list = zeros(k, length(m_list))

Threads.@threads for i in 1:length(m_list)
    m = m_list[i]
    F_sub = sample_fourier(m, x_dim)  # subsampling DCT for measurement matrix
    F_sub = F_sub * sqrt(x_dim)/sqrt(m); #normalization  

    y = F_sub * G_inco(z_inco) # measurement vector using subsampled DCT matrix
    z_est_inco = randn(k) #initialization for algorithm
    z_est_inco = estimated_code(opt, G_inco, y, F_sub, z_est_inco; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_inco_list[:,i] = z_est_inco

    y = F_sub * G_co(z_co) # measurement vector using subsampled DCT matrix
    z_est_co = randn(k) #initialization for algorithm
    z_est_co = estimated_code(opt, G_co, y, F_sub, z_est_co; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_co_list[:,i] = z_est_co
end

# %%
anim = @animate for k ∈ 1:length(m_list)
    p1 = plot(colorview(Gray, reshape(G_inco(z_inco), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .81")
    p2 = plot(colorview(Gray, reshape(G_inco(z_est_inco_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    p3 = plot(colorview(Gray, reshape(G_co(z_co), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .97")
    p4 = plot(colorview(Gray, reshape(G_co(z_est_co_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    plot(p1, p2, p3, p4, layout = grid(2,2))
end

gif(anim, "anim_$num.gif", fps = 1)
# Out:
# ┌ Info: Saved animation to
# │   fn = c:\Users\Babhru\Documents\GitHub\GNN_Isometries\anim_3.gif
# └ @ Plots C:\Users\Babhru\.julia\packages\Plots\E2187\src\animation.jl:126
# Plots.AnimatedGif("c:\\Users\\Babhru\\Documents\\GitHub\\GNN_Isometries\\anim_3.gif")

# %%
# pick a image in MNIST to denoise
num = 4
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)

(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco)


# Load the model and test set loader unenforced
epoch_to_load_co = 20
dir_co = "trained_GNN/MNIST_v2"
encoder_μ_co, encoder_logvar_co, decoder_co, W3_co = load_model_identity(dir_co, epoch_to_load_co);
μ = encoder_μ_co(x_true)
logvar_co = encoder_logvar_co(x_true)
# Apply reparameterisation trick to sample latent
z_co = μ + randn(Float32, size(logvar_co)) .* exp.(0.5f0 * logvar_co)


#setup
x_dim = 784
k = 20
tolerance = 1e-7; max_iter = 3000; out_toggle = 0
opt = Flux.Optimise.ADAM(.1);

G_inco(z) = W3_inco *decoder_inco(z)
G_co(z) = W3_co *decoder_co(z)
colorview(Gray, reshape(G_co(z_co), 28,28)' )
# Out:
# Loading model...Done
# Loading model...Done
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# 28×28 reinterpret(reshape, Gray{Float64}, adjoint(::Matrix{Float64})) with eltype Gray{Float64}:
#  Gray{Float64}(11.2195)  Gray{Float64}(11.2182)  …  Gray{Float64}(11.2187)
#  Gray{Float64}(11.2196)  Gray{Float64}(11.2201)     Gray{Float64}(11.2195)
#  Gray{Float64}(11.2195)  Gray{Float64}(11.2194)     Gray{Float64}(11.2192)
#  Gray{Float64}(11.2192)  Gray{Float64}(11.2187)     Gray{Float64}(11.2196)
#  Gray{Float64}(11.2216)  Gray{Float64}(11.4386)     Gray{Float64}(11.2947)
#  Gray{Float64}(11.2183)  Gray{Float64}(11.2191)  …  Gray{Float64}(9.86793)
#  Gray{Float64}(11.2183)  Gray{Float64}(11.3102)     Gray{Float64}(8.85721)
#  Gray{Float64}(11.4255)  Gray{Float64}(9.63216)     Gray{Float64}(10.2546)
#  Gray{Float64}(11.3872)  Gray{Float64}(11.597)      Gray{Float64}(10.7802)
#  Gray{Float64}(11.0131)  Gray{Float64}(12.3955)     Gray{Float64}(10.491)
#  ⋮                                               ⋱
#  Gray{Float64}(11.3878)  Gray{Float64}(10.8499)     Gray{Float64}(11.0304)
#  Gray{Float64}(11.2218)  Gray{Float64}(10.601)   …  Gray{Float64}(11.3789)
#  Gray{Float64}(11.4101)  Gray{Float64}(10.3883)     Gray{Float64}(11.4807)
#  Gray{Float64}(11.4104)  Gray{Float64}(11.4469)     Gray{Float64}(11.4911)
#  Gray{Float64}(11.2185)  Gray{Float64}(11.2193)     Gray{Float64}(11.219)
#  Gray{Float64}(11.219)   Gray{Float64}(11.2216)     Gray{Float64}(11.2193)
#  Gray{Float64}(11.2198)  Gray{Float64}(11.2203)  …  Gray{Float64}(11.22)
#  Gray{Float64}(11.2192)  Gray{Float64}(11.2198)     Gray{Float64}(11.2187)
#  Gray{Float64}(11.2198)  Gray{Float64}(11.22)       Gray{Float64}(11.2197)

# %%
m_list = 10:5:100
z_est_inco_list = zeros(k, length(m_list))
z_est_co_list = zeros(k, length(m_list))

Threads.@threads for i in 1:length(m_list)
    m = m_list[i]
    F_sub = sample_fourier(m, x_dim)  # subsampling DCT for measurement matrix
    F_sub = F_sub * sqrt(x_dim)/sqrt(m); #normalization  

    y = F_sub * G_inco(z_inco) # measurement vector using subsampled DCT matrix
    z_est_inco = randn(k) #initialization for algorithm
    z_est_inco = estimated_code(opt, G_inco, y, F_sub, z_est_inco; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_inco_list[:,i] = z_est_inco

    y = F_sub * G_co(z_co) # measurement vector using subsampled DCT matrix
    z_est_co = randn(k) #initialization for algorithm
    z_est_co = estimated_code(opt, G_co, y, F_sub, z_est_co; max_iter, tolerance, out_toggle)  # run a optimizer to solve the least squares problem
    z_est_co_list[:,i] = z_est_co
end

anim = @animate for k ∈ 1:length(m_list)
    p1 = plot(colorview(Gray, reshape(G_inco(z_inco), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .81")
    p2 = plot(colorview(Gray, reshape(G_inco(z_est_inco_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    p3 = plot(colorview(Gray, reshape(G_co(z_co), 28,28)' ), framestyle = :none, bg =:black, title = "original image, α ≤ .97")
    p4 = plot(colorview(Gray, reshape(G_co(z_est_co_list[:, k]), 28,28)' ), framestyle = :none, bg =:black, title = "m = $(m_list[k])")

    plot(p1, p2, p3, p4, layout = grid(2,2))
end

gif(anim, "anim_$num.gif", fps = 1)
# Out:
# ┌ Info: Saved animation to
# │   fn = c:\Users\Babhru\Documents\GitHub\GNN_Isometries\anim_4.gif
# └ @ Plots C:\Users\Babhru\.julia\packages\Plots\E2187\src\animation.jl:126
# Plots.AnimatedGif("c:\\Users\\Babhru\\Documents\\GitHub\\GNN_Isometries\\anim_4.gif")

# %%
# pick a image in MNIST to denoise
num = 4
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)
(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ1 = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ1 + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco);
# Out:
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# Loading model...Done

# %%
# pick a image in MNIST to denoise
num = 9
batch_size = 64
shuffle_data = true
dataloader = get_train_loader(batch_size, shuffle_data)
(x_batch, y_batch) = first(dataloader)
i = 1
while y_batch[i] != num
    i += 1
end

x_true= x_batch[:,i];
# Load the model and test set loader incoherent
epoch_to_load_inco = 20
dir_inco = "trained_GNN/MNIST_identity_v2"
encoder_μ_inco, encoder_logvar_inco, decoder_inco, W3_inco = load_model_identity(dir_inco, epoch_to_load_inco);
μ2 = encoder_μ_inco(x_true)
logvar_inco = encoder_logvar_inco(x_true)
# Apply reparameterisation trick to sample latent
z_inco = μ2 + randn(Float32, size(logvar_inco)) .* exp.(0.5f0 * logvar_inco);
# Out:
# ┌ Warning: MNIST.traindata() is deprecated, use `MNIST(split=:train)[:]` instead.
# └ @ MLDatasets C:\Users\Babhru\.julia\packages\MLDatasets\Xb4Lh\src\datasets\vision\mnist.jl:187
# Loading model...Done

# %%
norm(z_inco)
# Out:
# 4.3862915f0

# %%
sqrt(20)
# Out:
# 4.47213595499958

# %%
Threads.nthreads()
# Out:
# 12
